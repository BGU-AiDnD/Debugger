# %%
import nlp_model
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 23 days
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 23 days

# %%
nlp_model.build_model?

# %%
nlp_model.build_model(r"C:\Temp\Ant_for_NLP.csv", size=20)

# %%
m = _

# %%
m

# %%
m.vocab.keys()
# Out:
# ['proposal/myrmidon/src/main/org/apache/tools/zip/ZipShort.java',
#  'src/tests/junit/org/apache/tools/ant/taskdefs/optional/junit/JUnitTestListenerTest.java',
#  'proposal/myrmidon/src/todo/org/apache/tools/ant/util/regexp/Jdk14RegexpMatcher.java',
#  'src/testcases/org/apache/tools/ant/taskdefs/AntTest.java',
#  'src/main/org/apache/tools/ant/taskdefs/optional/starteam/StarTeamList.java',
#  'proposal/sandbox/junit/src/main/org/apache/tools/ant/taskdefs/optional/junit/WatchdogTest.java',
#  'proposal/myrmidon/src/todo/org/apache/tools/todo/taskdefs/Rpm.java',
#  'src/main/org/apache/tools/ant/taskdefs/compilers/Jikes.java',
#  'proposal/myrmidon/src/java/org/apache/ant/modules/basic/StringToByteConverter.java',
#  'proposal/myrmidon/src/java/org/apache/ant/modules/basic/AntCall.java',
#  'src/testcases/org/apache/tools/ant/taskdefs/optional/sitraka/ClassPathLoaderTest.java',
#  'src/testcases/org/apache/tools/ant/taskdefs/optional/junit/NoVmCrash.java',
# ...

# %%
m.score(m.vocab.keys()[:3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-fb3e5e4f831d> in <module>()
# ----> 1 m.score(m.vocab.keys()[:3])
#
# C:\Users\User\Anaconda2\lib\site-packages\gensim\models\word2vec.pyc in score(self, sentences, total_sentences, chunksize, queue_factor, report_delay)
#     878
#     879         sentence_count = 0
# --> 880         sentence_scores = matutils.zeros_aligned(total_sentences, dtype=REAL)
#     881
#     882         push_done = False
#
# C:\Users\User\Anaconda2\lib\site-packages\gensim\matutils.pyc in zeros_aligned(shape, dtype, order, align)
#     145     """Like `numpy.zeros()`, but the array will be aligned at `align` byte boundary."""
#     146     nbytes = numpy.prod(shape, dtype=numpy.int64) * numpy.dtype(dtype).itemsize
# ...
